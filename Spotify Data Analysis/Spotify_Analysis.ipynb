# %% [markdown]
# #### Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load the dataset

# %%
df_tracks = pd.read_csv('tracks.csv')
df_tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %% [markdown]
# #### Display data information

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %% [markdown]
# #### Check for null values

# %%
pd.isnull(df_tracks).sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %% [markdown]
# #### Generate descriptive statistics

# %%
df_tracks.describe().transpose()
# Out:
#                      count           mean            std     min          25%  \
# popularity        586672.0      27.570053      18.370642     0.0      13.0000
# duration_ms       586672.0  230051.167286  126526.087418  3344.0  175093.0000
# explicit          586672.0       0.044086       0.205286     0.0       0.0000
# danceability      586672.0       0.563594       0.166103     0.0       0.4530
# energy            586672.0       0.542036       0.251923     0.0       0.3430
# key               586672.0       5.221603       3.519423     0.0       2.0000
# loudness          586672.0     -10.206067       5.089328   -60.0     -12.8910
# mode              586672.0       0.658797       0.474114     0.0       0.0000
# speechiness       586672.0       0.104864       0.179893     0.0       0.0340
# acousticness      586672.0       0.449863       0.348837     0.0       0.0969
# instrumentalness  586672.0       0.113451       0.266868     0.0       0.0000
# ...

# %% [markdown]
# #### 1. 10 Least popular songs

# %%
least = df_tracks.sort_values('popularity', ascending = True)
least.head(10)
# Out:
#                             id  \
# 546130  181rTRhCcggZPwP2TUcVqm
# 546222  0yOCz3V5KMm8l1T8EFc60i
# 546221  0y48Hhwe52099UqYjegRCO
# 546220  0xCmgtf9ka07hkZg3D6PaV
# 546219  0tBXS3VuCPX7KWUFH2nros
# 546218  0qrKnQtYDVJhKFAXTHYVS9
# 546217  0nqsDxOeKSwEzp3AUQAAqS
# 546216  0kGEdsxVLYjCdfxM9tbezd
# 546215  0bc3PUZurUUXrY7yqoOxjq
# 546214  0Wwm0ruSjYMIiWG0nyAI1F
#
#                                                      name  popularity  \
# 546130       Newspaper Reports On Abner, 20 February 1935           0
# 546222                                             恋は水の上で           0
# 546221                                              私の誕生日           0
# 546220                                エル・チョクロ (EL CHOCLO)           0
# 546219                                           恋は不思議なもの           0
# 546218                         ゆうべはどうしたの (WHATSA MALLA U)           0
# 546217  Screen Director's Playhouse, Music For Million...           0
# ...

# %% [markdown]
# #### 2. Songs with a popularity score higher than 90

# %%
popular = df_tracks.query('popularity > 90', inplace = False).sort_values('popularity', ascending = False)
popular.head(10)
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 92813  0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 92814  6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 91866  60ynsPSSKe6O3sfwRnIBRf                                 Streets
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp                  Heartbreak Anniversary
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# ...

# %% [markdown]
# #### 3. Artist present in the 10th row

# %%
df_tracks[['artists']].iloc[9]
# Out:
# artists    ['Ignacio Corsini']
# Name: 9, dtype: object

# %% [markdown]
# #### 4. Correlation heatmap between variable

# %%
# Select only numeric columns (assuming all non-numeric columns should be excluded)
numeric_columns = df_tracks.select_dtypes(include=[np.number])

# Calculate the correlation matrix
corr_df = numeric_columns.corr(method='pearson')

# %%
corr_df
# Out:
#                   popularity  duration_ms  explicit  danceability    energy  \
# popularity          1.000000     0.027681  0.211758      0.187000  0.302315
# duration_ms         0.027681     1.000000 -0.016747     -0.120371  0.024825
# explicit            0.211758    -0.016747  1.000000      0.150229  0.123076
# danceability        0.187000    -0.120371  0.150229      1.000000  0.241563
# energy              0.302315     0.024825  0.123076      0.241563  1.000000
# key                 0.015299     0.004626  0.010932      0.018824  0.036294
# loudness            0.327028     0.000337  0.134603      0.251436  0.764735
# mode               -0.033655    -0.027610 -0.051754     -0.044719 -0.065246
# speechiness        -0.047357    -0.125771  0.102258      0.199310 -0.053506
# acousticness       -0.370882    -0.064434 -0.149018     -0.242951 -0.715412
# instrumentalness   -0.236487     0.069278 -0.067520     -0.225900 -0.195839
# ...

# %%
plt.figure(figsize=(12, 6))
heatmap = sns.heatmap(corr_df, annot=True, fmt='.1g', vmin=-1, center=0, cmap='inferno', linewidths=1, linecolor='black')
heatmap.set_title("Correlation Heatmap Between Variables")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap Between Variables')

# %% [markdown]
# #### Create a sample by taking .4% of the total data

# %%
sample_df = df_tracks.sample(int(0.004*len(df_tracks)))
print(len(sample_df))
# Out:
# 2346

# %% [markdown]
# #### 5. Regression plot between loudness and Energy

# %%
plt.figure(figsize=(10,5))
sns.regplot(data = df_tracks, y='loudness', x='energy', color='c').set(title='Loudness vs Energy Correlation')
# Out:
# [Text(0.5, 1.0, 'Loudness vs Energy Correlation')]

# %% [markdown]
# #### 6. Regression plot between Popularity and Acousticness

# %%
plt.figure(figsize=(10,5))
sns.regplot(data = sample_df, y='popularity', x='acousticness', color='b').set(title='Popularity vs Acousticness Correlation')
# Out:
# [Text(0.5, 1.0, 'Popularity vs Acousticness Correlation')]

# %% [markdown]
# #### Remove rows with invalid date values

# %%
df_tracks = df_tracks[df_tracks['release_date'].str.match(r'\d{4}-\d{2}-\d{2}')]

# %% [markdown]
# #### Set the release date column as the index

# %%
df_tracks.set_index('release_date', inplace=True)
df_tracks.index = pd.to_datetime(df_tracks.index)

# %%
df_tracks
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-03-29    0JV4iqw2lSKJaHBQZ0e5zK        Martín Fierro - Remasterizado
# ...                              ...                                  ...
# 2020-09-26    5rgu12WBIHQtvej2MdHSH0                                  云与海
# 2020-10-21    0NuWgxEp51CutD2pJoF4OM                                blind
# 2020-09-02    27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 2021-03-05    45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 2015-07-01    5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#               popularity  duration_ms  explicit  \
# release_date
# ...

# %% [markdown]
# #### Create a new column called years from release date column

# %%
df_tracks.index
# Out:
# DatetimeIndex(['1922-02-22', '1922-06-01', '1922-03-21', '1922-03-21',
#                '1922-03-29', '1922-06-01', '1922-06-01', '1922-02-22',
#                '1922-06-01', '1922-06-01',
#                ...
#                '2020-12-20', '2020-12-29', '2020-03-03', '2020-03-20',
#                '2020-02-08', '2020-09-26', '2020-10-21', '2020-09-02',
#                '2021-03-05', '2015-07-01'],
#               dtype='datetime64[ns]', name='release_date', length=448081, freq=None)

# %%
df_tracks.index.get_level_values('release_date')
# Out:
# DatetimeIndex(['1922-02-22', '1922-06-01', '1922-03-21', '1922-03-21',
#                '1922-03-29', '1922-06-01', '1922-06-01', '1922-02-22',
#                '1922-06-01', '1922-06-01',
#                ...
#                '2020-12-20', '2020-12-29', '2020-03-03', '2020-03-20',
#                '2020-02-08', '2020-09-26', '2020-10-21', '2020-09-02',
#                '2021-03-05', '2015-07-01'],
#               dtype='datetime64[ns]', name='release_date', length=448081, freq=None)

# %%
df_tracks['dates'] = df_tracks.index.get_level_values('release_date')
df_tracks.dates = pd.to_datetime(df_tracks.dates)
years = df_tracks.dates.dt.year

# %%
years
# Out:
# release_date
# 1922-02-22    1922
# 1922-06-01    1922
# 1922-03-21    1922
# 1922-03-21    1922
# 1922-03-29    1922
#               ...
# 2020-09-26    2020
# 2020-10-21    2020
# 2020-09-02    2020
# 2021-03-05    2021
# 2015-07-01    2015
# Name: dates, Length: 448081, dtype: int32

# %% [markdown]
# #### 7. Distribution plot (bar plot) for total number of song per year

# %%
plt.figure(figsize=(10,5))
sns.displot(years,discrete=True,aspect=2,height=5,kind='hist').set(title='Number of songs per year')

# %% [markdown]
# #### Convert milliseconds to seconds

# %%
df_tracks['duration'] = df_tracks['duration_ms'].apply(lambda x: round(x/1000))
df_tracks.drop('duration_ms', inplace = True, axis = 1)

# %% [markdown]
# #### 8. Duration of the songs over the years

# %%
total_dr = df_tracks.duration

# %%
total_dr
# Out:
# release_date
# 1922-02-22    127
# 1922-06-01     98
# 1922-03-21    182
# 1922-03-21    177
# 1922-03-29    181
#              ...
# 2020-09-26    258
# 2020-10-21    153
# 2020-09-02    188
# 2021-03-05    142
# 2015-07-01    214
# Name: duration, Length: 448081, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(18, 8))
sns.barplot(x=years, y=total_dr, ax=ax)
ax.set(title='Year vs Duration')
plt.xticks(rotation=90)
ax.set_xlabel('Year')  # Add x-axis label
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# #### 9. Line plot for average duration of the songs over the years

# %%
total_dr = df_tracks.duration

# %%
total_dr
# Out:
# release_date
# 1922-02-22    127
# 1922-06-01     98
# 1922-03-21    182
# 1922-03-21    177
# 1922-03-29    181
#              ...
# 2020-09-26    258
# 2020-10-21    153
# 2020-09-02    188
# 2021-03-05    142
# 2015-07-01    214
# Name: duration, Length: 448081, dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x=years, y=total_dr)
plt.title('Year vs Duration')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# #### Load the second dataset

# %%
df_genre = pd.read_csv('SpotifyFeatures.csv')
df_genre.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %% [markdown]
# #### 10. Duration of the song for different genres

# %%
plt.figure(figsize=(10, 5))
sns.color_palette('rocket', as_cmap = True)
sns.barplot(y='genre', x='duration_ms', data=df_genre)
plt.title('Duration of the songs in different genres')
plt.xlabel("Duration in milli seconds")
plt.ylabel('Genres')
# Out:
# Text(0, 0.5, 'Genres')

# %% [markdown]
# #### 11. Top 5 genres by popularity

# %%
famous = df_genre.sort_values('popularity', ascending = False).head(10)
plt.figure(figsize = (10,5))
sns.set_style(style = 'darkgrid')
sns.barplot(y='genre', x='popularity', data= famous).set(title = "Top 5 genres by popularity")
# Out:
# [Text(0.5, 1.0, 'Top 5 genres by popularity')]
